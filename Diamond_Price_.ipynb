# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train.csv")
df
# Out:
#           Id  carat        cut color clarity  depth  table  price     x     y  \
# 0          1   1.06      Ideal     I     SI2   61.8   57.0   4270  6.57  6.60
# 1          2   1.51    Premium     G    VVS2   60.9   58.0  15164  7.38  7.42
# 2          3   0.32      Ideal     F     VS2   61.3   56.0    828  4.43  4.41
# 3          4   0.53      Ideal     G     VS2   61.2   56.0   1577  5.19  5.22
# 4          5   0.70    Premium     H    VVS2   61.0   57.0   2596  5.76  5.72
# ...      ...    ...        ...   ...     ...    ...    ...    ...   ...   ...
# 43147  43148   0.52      Ideal     E     VS2   61.5   56.0   1760  5.16  5.18
# 43148  43149   0.72  Very Good     D     VS2   62.1   59.0   3016  5.70  5.73
# 43149  43150   0.44    Premium     I    VVS1   61.5   58.0    990  4.95  4.87
# 43150  43151   0.31    Premium     E     VS1   60.2   58.0    734  4.38  4.43
# 43151  43152   0.33      Ideal     G     VS2   61.2   55.0    743  4.49  4.46
#
#           z
# 0      4.07
# 1      4.51
# 2      2.71
# 3      3.19
# 4      3.50
# ...     ...
# 43147  3.18
# 43148  3.55
# 43149  3.02
# 43150  2.65
# 43151  2.74
#
# [43152 rows x 11 columns]

# %% [markdown]
# # data analysis

# %%
df.describe()
# Out:
#                  Id         carat         depth         table         price  \
# count  43152.000000  43152.000000  43152.000000  43152.000000  43152.000000
# mean   21576.500000      0.797855     61.747177     57.458347   3929.491912
# std    12457.053745      0.473594      1.435454      2.233904   3985.527795
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    10788.750000      0.400000     61.000000     56.000000    947.750000
# 50%    21576.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    32364.250000      1.040000     62.500000     59.000000   5312.000000
# max    43152.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  43152.000000  43152.000000  43152.000000
# mean       5.731568      5.735018      3.538568
# std        1.121279      1.148809      0.708238
# min        0.000000      0.000000      0.000000
# 25%        4.710000      4.720000      2.910000
# 50%        5.700000      5.710000      3.530000
# 75%        6.540000      6.540000      4.040000
# max       10.740000     58.900000     31.800000

# %%
df.isnull().sum()
# Out:
# Id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43152 entries, 0 to 43151
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Id       43152 non-null  int64
#  1   carat    43152 non-null  float64
#  2   cut      43152 non-null  object
#  3   color    43152 non-null  object
#  4   clarity  43152 non-null  object
#  5   depth    43152 non-null  float64
#  6   table    43152 non-null  float64
#  7   price    43152 non-null  int64
#  8   x        43152 non-null  float64
#  9   y        43152 non-null  float64
#  10  z        43152 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 3.6+ MB

# %%
df["cut"].unique()
# Out:
# array(['Ideal', 'Premium', 'Very Good', 'Fair', 'Good'], dtype=object)

# %% [markdown]
# Ideal
#
# Premium
#
# Very good
#
# Good
#
# Fair
#
# Poor

# %%
df["cut"].value_counts()
# Out:
# cut
# Ideal        17203
# Premium      11113
# Very Good     9658
# Good          3881
# Fair          1297
# Name: count, dtype: int64

# %%
df["clarity"].unique()
# Out:
# array(['SI2', 'VVS2', 'VS2', 'IF', 'VS1', 'SI1', 'VVS1', 'I1'],
#       dtype=object)

# %%
df["clarity"].value_counts()
# Out:
# clarity
# SI1     10428
# VS2      9824
# SI2      7432
# VS1      6475
# VVS2     4041
# VVS1     2904
# IF       1442
# I1        606
# Name: count, dtype: int64

# %%
df["color"].unique()
# Out:
# array(['I', 'G', 'F', 'H', 'D', 'E', 'J'], dtype=object)

# %%
df["color"].value_counts()
# Out:
# color
# G    9060
# E    7832
# F    7633
# H    6651
# D    5421
# I    4265
# J    2290
# Name: count, dtype: int64

# %% [markdown]
# #Data Visualization

# %%
corr_data=df.drop(['color','clarity','cut'],axis=1)

# %%
sns.heatmap(corr_data.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
sns.pairplot(df)

# %% [markdown]
# #processing data

# %% [markdown]
# there outleyer in the y, x
#
#
# there is high  linear relation between carat and price

# %%
sns.scatterplot(x=df["carat"], y = df["price"])
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
df[df["carat"] > 3].shape
# Out:
# (21, 11)

# %%
df["carat"] = df["carat"].replace(0, df["carat"].min())

# %%
sns.scatterplot(x=df["carat"], y = df["price"])
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x=df["x"], y = df["price"])
# Out:
# <Axes: xlabel='x', ylabel='price'>

# %%
sns.scatterplot(x=df["y"], y = df["price"])
# Out:
# <Axes: xlabel='y', ylabel='price'>

# %%
sns.scatterplot(x=df["z"], y = df["price"])
# Out:
# <Axes: xlabel='z', ylabel='price'>

# %%
sns.scatterplot(x= df["depth"] , y=df["price"])
# Out:
# <Axes: xlabel='depth', ylabel='price'>

# %%
sns.scatterplot(x= df["table"] , y=df["price"])
# Out:
# <Axes: xlabel='table', ylabel='price'>

# %% [markdown]
# # Work on outliers

# %%
carat_index = list(df[df["carat"] >= 3].index)
x_index = list(df[df["x"] < 2 ].index)
y_index = list(df[df["y"] > 30 ].index)
z_index = list(df[df["z"] > 30 ].index)
z_index2 = list(df[df["z"] < 2].index)
depth_index = list(df[(df["depth"] > 75) | (df["depth"] < 45 )].index)
table_index = list(df[df["table"] > 90].index)

indexes = carat_index + x_index + y_index + z_index + z_index2+depth_index + table_index
for outlier in indexes:
    df.drop(outlier, inplace=True)

# %%
sns.scatterplot(x=df["carat"], y = df["price"])
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x=df["x"], y = df["price"])
# Out:
# <Axes: xlabel='x', ylabel='price'>

# %%
sns.scatterplot(x=df["y"], y = df["price"])
# Out:
# <Axes: xlabel='y', ylabel='price'>

# %%
sns.scatterplot(x=df["z"], y = df["price"])
# Out:
# <Axes: xlabel='z', ylabel='price'>

# %% [markdown]
#  # Visualization of Categorical data

# %%
sns.countplot(df["cut"],palette="Set1",color='b')
# Out:
# <ipython-input-107-e2ba8a0e9917>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df["cut"],palette="Set1",color='b')
# <Axes: xlabel='count', ylabel='cut'>

# %%
sns.countplot(df["clarity"], palette='rocket')
# Out:
# <ipython-input-108-2463b4fd66cd>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df["clarity"], palette='rocket')
# <Axes: xlabel='count', ylabel='clarity'>

# %%
sns.countplot(df["color"], palette='Set1')
# Out:
# <ipython-input-109-e7977da7a937>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df["color"], palette='Set1')
# <Axes: xlabel='count', ylabel='color'>

# %% [markdown]
# # processing Categorical data

# %%
def grade(x):
    x = str(x)
    if x == "Fair":
        return 1
    elif x == "Good":
        return 2
    elif x == "Very Good":
        return 3
    elif x == "Premium":
        return 4
    elif x == "Ideal":
        return 5
def color_grade(x):
    x = str(x)
    if x == "J":
        return 1
    elif x == "I":
        return 1
    elif x == "H":
        return 2
    elif x == "G":
        return 3
    elif x == "F":
        return 4
    elif x == "E":
        return 5
    elif x == "D":
        return 6
def clarity_quality(x):
    x = str(x)
    if x == "I1":
        return 1
    elif x == "SI2":
        return 2
    elif x == "SI1":
        return 3
    elif x == "VS2":
        return 4
    elif x == "VS1":
        return 5
    elif x == "VVS2":
        return 6
    elif x == "VVS1":
        return 7
    elif x == "IF":
        return 8

# %%
df["cut_grade"] = df["cut"].apply(grade)
df["color_grade"] = df["color"].apply(color_grade)
df["clarity_grade"] = df["clarity"].apply(clarity_quality)

# %%
df.drop(["cut","color","clarity","depth","table"], inplace=True, axis=1)

# %%
df.head()
# Out:
#    Id  carat  price     x     y     z  cut_grade  color_grade  clarity_grade
# 0   1   1.06   4270  6.57  6.60  4.07          5            1              2
# 1   2   1.51  15164  7.38  7.42  4.51          4            3              6
# 2   3   0.32    828  4.43  4.41  2.71          5            4              4
# 3   4   0.53   1577  5.19  5.22  3.19          5            3              4
# 4   5   0.70   2596  5.76  5.72  3.50          4            2              6

# %%
test_data=pd.read_csv("test.csv")
for outlier in indexes:
    test_data.drop(outlier, inplace=True)
test_data["cut_grade"] = test_data["cut"].apply(grade)
test_data["color_grade"] = test_data["color"].apply(color_grade)
test_data["clarity_grade"] = test_data["clarity"].apply(clarity_quality)
test_data.drop(["cut","color","clarity","depth","table"], inplace=True, axis=1)

# %%
test_data.head()
# Out:
#    Id  carat     x     y     z  cut_grade  color_grade  clarity_grade
# 0   1   0.34  4.52  4.48  2.75          5            3              6
# 1   2   0.71  5.74  5.68  3.58          4            5              4
# 2   3   0.44  4.83  4.88  3.05          3            1              5
# 3   4   0.81  6.09  6.03  3.65          4            5              2
# 4   5   0.40  4.74  4.80  2.92          5            3              7

# %% [markdown]
# # Machine Learning models

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
x = df.drop(["price"], axis = 1)
y = df["price"]
X_train, X_test, X_train, y_test = train_test_split(X,y, test_size=0.25, random_state=42)

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
forest_reg = RandomForestRegressor()
forest_reg.fit(X_train, X_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=forest_reg.predict(X_test)

# %%
from sklearn.model_selection import cross_val_score

forest_score = cross_val_score(forest_reg, X_train, y_train, cv=10)
print("Cross-validation score:", forest_score.mean())

# %%
import joblib

joblib.dump(forest_score, "forest_reg.pkl")
# Out:
# ['forest_reg.pkl']

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
    {'n_estimators': [30,31,32,33], 'max_features': [4,6,8,10]},
    {'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [ 4,5,6]},
  ]

grid_search = GridSearchCV(forest_reg, param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           return_train_score=True)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid=[{'max_features': [4, 6, 8, 10],
#                           'n_estimators': [30, 31, 32, 33]},
#                          {'bootstrap': [False], 'max_features': [4, 5, 6],
#                           'n_estimators': [3, 10]}],
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_params_
# Out:
# {'max_features': 4, 'n_estimators': 33}

# %%
final_model = grid_search.best_estimator_

# %%
from sklearn.metrics import mean_squared_error
final_predictions = final_model.predict(X_test)
final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)
final_rmse
# Out:
# 591.765616801618

# %% [markdown]
# # linear regrassion

# %%
from sklearn.linear_model import LinearRegression
model_linear=LinearRegression()
model_linear.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model_linear.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
mean_s= mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mean_s)
rmse
# Out:
# 1153.578190529154

# %% [markdown]
# #  Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

model_deployment = DecisionTreeRegressor(max_depth = 7,random_state=400)
model_deployment.fit(X_train, y_train)
y_pred = model_deployment.predict(X_test)
#Model score
print("Model train accuracy score is :", model_deployment.score(X_train, y_train))
print("Model test accuracy score is :", model_deployment.score(X_test, y_test))
# Out:
# Model train accuracy score is : 0.9657633976540059
# Model test accuracy score is : 0.9606523969576248

# %% [markdown]
# find best depth

# %%
depths = [i for i in range(1, 25)]
train_score = []
test_score = []

for i in depths:
    DTR = DecisionTreeRegressor(max_depth = i)
    DTR.fit(X_train, y_train)
    train_score.append(DTR.score(X_train, y_train))
    test_score.append(DTR.score(X_test, y_test))

plt.plot(depths, train_score, label="Training")
plt.plot(depths, test_score, label="Testing")
plt.xlabel("Max_depth")
plt.ylabel("Train, Test scores")
plt.title("Decision Tree Regressor")
plt.show()

# %%
from sklearn.metrics import r2_score, mean_squared_error

print("R2_Score is: ", r2_score(y_test, y_pred).round(4))
# Out:
# R2_Score is:  0.9607

# %%
tree_mse = mean_squared_error(y_test, y_pred)
tree_rmse = np.sqrt(tree_mse)
tree_rmse
# Out:
# 783.4964168719684

# %% [markdown]
# ## the bwst model for project is Random Forest model with rmse = 591.765616801618
